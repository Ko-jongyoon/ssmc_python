# %%
from bs4 import BeautifulSoup
import urllib.request as REQ

# %%
url = 'https://news.naver.com/'
response= REQ.urlopen(url)
soup = BeautifulSoup(response,'html.parser')
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="http://news.naver.com/main/home.nhn" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image">
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" name="twitter:image"/>
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
# <title>네이버 뉴스</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20190110_155303/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20190110_155303/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20190110_155303/js/news.jindo.js" type="text/javascript"></script>
# <script type="text/javascript">
# document.domain='naver.com';
# var _MAIN_NEWS_MENU_ID='home';
# var _MAIN_NEWS_SECTION_ID='100';
# var ccsrv='cc.naver.com';
# var g_ssc='news.home';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout='https://news.naver.com';
# var gnb_template='gnb_utf8';
# var gnb_brightness = 1;
# var gnb_one_naver = 1;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Tue Jan 22 11:22:15 KST 2019";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20190110_155303/js/news.service.js" type="text/javascript"></script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_wrap">
# <!-- GNB 마크업 -->
# <div id="gnb"></div>
# <!-- //GNB 마크업 -->
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(STA.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(STA.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="nclicks(STA.enter)" href="https://entertain.naver.com/home"><img alt="TV연예" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_entertain.png" width="52"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.sports)" href="https://sports.news.naver.com"><img alt="스포츠" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_sports.png" width="48"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.newsstand)" href="https://newsstand.naver.com"><img alt="뉴스스탠드" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_newsstand.png" width="77"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.weather)" href="https://weather.naver.com"><img alt="날씨" height="19" src="https://imgnews.pstatic.net/image/news/2017/10/snb_h_weather.png" width="31"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li class="lnb_menu_home on"><a class="nclicks(LNB.home)" href="/main/home.nhn"><span class="tx">뉴스홈</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(LNB.flash)" href="/main/list.nhn?mode=LSD&amp;mid=sec&amp;sid1=001"><span class="tx">속보</span></a></li>
# <li><a class="nclicks(LNB.pol)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(LNB.eco)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(LNB.soc)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(LNB.lif)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(LNB.wor)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(LNB.sci)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(LNB.opi)" href="/main/opinion/home.nhn"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(LNB.pho)" href="/main/photo/index.nhn?mid=pho"><span class="tx">포토</span> </a></li>
# <li><a class="nclicks(LNB.tv)" href="/main/tv/index.nhn?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(LNB.ranking)" href="/main/ranking/popularDay.nhn?mid=etc&amp;sid1=111"><span class="tx">랭킹뉴스</span> </a></li>
# </ul>
# <form accept-charset="UTF-8" action="https://search.naver.com/search.naver" id="lnb.searchForm" method="get" name="lnb_searchForm" target="_blank">
# <fieldset>
# <legend>뉴스 검색</legend>
# <input accesskey="s" class="text_index" name="query" style="ime-mode:active;" title="뉴스 검색" type="text"/>
# <input name="where" type="hidden" value="news"/>
# <input name="ie" type="hidden" value="utf8"/>
# <input name="sm" type="hidden" value="nws_hty"/>
# <button class="btn_search_lnb nclicks(LNB.search)" type="submit"><span class="tx"><span class="blind">검색</span></span></button>
# </fieldset>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="home_timelate">
# <div class="ht_head">
# <ul class="ht_tabmnu">
# <li id="ht_tabmnu_0">
# <a href="#" title="신문 헤드라인">신문 헤드라인<span class="ht_ico"></span></a>
# </li>
# <li id="ht_tabmnu_1">
# <a href="#" title="저녁 방송 뉴스">저녁 방송 뉴스<span class="ht_ico"></span></a>
# </li>
# </ul>
# <ul class="lnb_side" tabindex="0">
# <li>
# <a class="nclicks(nct.right1)" href="https://news.naver.com/main/factcheck/main.nhn" title="팩트체크">팩트체크
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right2)" href="https://news.naver.com/main/officeList.nhn" title="언론사 뉴스">언론사 뉴스
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right3)" href="https://m.news.naver.com/hotissue/main.nhn?sid1=110&amp;cid=1083360" target="_blank" title="구독 이벤트">구독 이벤트
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리
# </a>
# </li>
# <li class="end">
# <a class="nclicks(nct.right5)" href="https://news.naver.com/main/history/mainnews/index.nhn" title="이 시각 주요뉴스 배열 이력">기사배열 이력
# </a>
# </li>
# </ul>
# </div>
# <div class="ht_comp ht_paperheadline" id="paperHeadlineRolling" style="display: none;">
# <h3 class="blind">신문 헤드라인</h3>
# <ul class="ht_ph_lst" style="display: none;">
# <!-- 헤드라인 데이터 동적삽입 <li> -->
# </ul>
# <div class="ht_nodata_all" style="display: none;">발행된 종이신문이 없거나 신문게재 정보가 입력되지 않았습니다.</div>
# <div class="ht_navi">
# <a class="ht_btn_prev nclicks(opt.prev)" href="javascript:;"><span class="ht_ico"></span><span class="blind">이전</span></a>
# <a class="ht_btn_next nclicks(opt.next)" href="javascript:;"><span class="ht_ico"></span><span class="blind">다음</span></a>
# <a class="ht_btn_fold nclicks(opt.open)" href="javascript:;"><span class="ht_btn_box"><span class="ht_btn_ico"></span><span class="blind">접기</span></span></a>
# </div>
# </div>
# <div class="ht_comp ht_eveningnews" id="eveningNewsRolling" style="display: none;">
# <h3 class="blind">저녁 방송 뉴스</h3>
# <ul class="ht_ph_lst">
# <!-- 저녁방송뉴스 동적삽입 <li> -->
# </ul>
# <div class="ht_navi">
# <a class="ht_btn_prev nclicks(opt.prev);" href="javascript:;"><span class="ht_ico"></span><span class="blind">이전</span></a>
# <a class="ht_btn_next nclicks(opt.next)" href="javascript:;"><span class="ht_ico"></span><span class="blind">다음</span></a>
# <a class="ht_btn_fold nclicks(opt.open)" href="javascript:;"><span class="ht_btn_box"><span class="ht_btn_ico"></span><span class="blind">접기</span></span></a>
# </div>
# </div>
# <script type="text/javascript">
# _oTopComponentData = {
# "open" : "N",
# "target" : "headlineList",
# "headlineList" : [
# {
# "officeId" : "008",
# "officeName" : "머니투데이",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/008/2017/01/05/logo_008_1_20170105110505.gif' width='206' height='30' alt='머니투데이' title='' class='' >",
# "thumbnail" : "",
# "title" : "KCGI, 한진에 이사 2명 선임 요구…\'정면충돌\' 예고",
# "summary" : "[머니투데이 신아름 기자, 송정훈 기자] [[주주 행동주의 원년...\'주총 전쟁\' 시작됐다]<2>①한진그룹(상보)] 행동주의 사모펀드 KCGI가 한진그룹에 지배구조 개선을 공개적으로 요구하고 나섰다. 한진그룹 주요 ",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "044",
# "officeName" : "코리아헤럴드",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/044/2017/01/05/logo_044_1_20170105110505.gif' width='206' height='30' alt='코리아헤럴드' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/044/2019/01/21/207471.jpg?type=nf80_54",
# "title" : "Trump touts NK developments as ‘historic result’",
# "summary" : "US President Donald Trump identified his nuclear talks with North Korea as among his greatest achievements in the first ",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "009",
# "officeName" : "매일경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/009/2017/01/05/logo_009_1_20170105110505.gif' width='206' height='30' alt='매일경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/009/2019/01/21/4292640.jpg?type=nf80_54",
# "title" : "`콩나물시루` 제주공항…불안한 관광객",
# "summary" : "신공항, 주민반발 4년 표류 작년 수용능력 300만명 초과 관광객은 3년째 급감 추세 지역경제에도 악영향 ◆ 멈춰선 국가프로젝트 ② ◆ 제주 출신으로 서울에서 직장을 다니는 김 모씨(49)는 이번 설 명절을 앞두고도",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "081",
# "officeName" : "서울신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/081/2017/01/05/logo_081_1_20170105110505.gif' width='206' height='30' alt='서울신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/081/2019/01/22/2971779.jpg?type=nf80_54",
# "title" : "메달 못따도 ‘졌잘싸’…한국 사회 바꾸는 힘",
# "summary" : "[서울신문] 정부, 즐기는 스포츠로 패러다임 전환 ‘국제대회 성적=국력’ 틀 벗어나야 “욕 먹을 각오로 개혁… 지금이 적기”‘한국 사회는 금메달을 포기할 준비가 됐습니까.’ 여자 쇼트트랙 간판 심석희(22·한국체대)",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "022",
# "officeName" : "세계일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/022/2017/01/05/logo_022_1_20170105110505.gif' width='206' height='30' alt='세계일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/022/2019/01/21/3335038.jpg?type=nf80_54",
# "title" : "[단독] \"성범죄·이혼 사건 돈 된다\" 변호사들 치열한 수임경쟁",
# "summary" : "불황이 가져온 업계 신풍속도 / 형사·가사법·이혼 전문 변호사 / 작년 933건 등록… 2010년 10배 / 전문카페 만들어 소개·알선까지 변호사 업계 불황으로 변호사들이 이른바 ‘돈이 되는’ 성범죄와 이혼, 가사 ",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "014",
# "officeName" : "파이낸셜뉴스",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/014/2017/01/05/logo_014_1_20170105110505.gif' width='206' height='30' alt='파이낸셜뉴스' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/014/2019/01/21/4164468.jpg?type=nf80_54",
# "title" : "[중국 성장률 28년만에 최저] \'톈안먼\'이후 최악 경제..차이나 쇼크 시작됐다",
# "summary" : "【 베이징·서울=조창원 특파원 박종원 기자】 올해 글로벌 경제에 중국 경제성장 침체가 최대 복병으로 등장했다. 중국의 지난해 경제성장률이 28년 만에 최저 수준을 기록하면서 \'차이나쇼크\' 우려가 커졌다. 중국 경기둔",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "023",
# "officeName" : "조선일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/023/2017/01/05/logo_023_1_20170105110505.gif' width='206' height='30' alt='조선일보' title='' class='' >",
# "thumbnail" : "",
# "title" : "손혜원 요구 거부한 국박 학예실장 교체",
# "summary" : "문체부·중앙박물관 관계자 증언 \"손혜원의 나전칠기 구입 종용에 현대미술관과 겹친다며 반대하자 중앙박물관, 작년 10월 인사 조치\" 목포 근대역사문화공간 투기 의혹을 받고 있는 손혜원 무소속 의원이 국립중앙박물관에 나",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "005",
# "officeName" : "국민일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/005/2017/01/05/logo_005_1_20170105110505.gif' width='206' height='30' alt='국민일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/005/2019/01/21/1166697.jpg?type=nf80_54",
# "title" : "[단독] 3·1운동 직후 日언론 “조선 무단통치 잘못”",
# "summary" : "3·1운동 직후 일본 내부에서 자국의 무단(武斷)통치에 대해 비판하는 목소리가 제기됐던 것으로 드러났다. 일본 주요 매체 보도를 모두 수집해 이 같은 흐름을 확인한 건 처음이다. 일제는 조선을 강점한 1910년부터 ",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "011",
# "officeName" : "서울경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/011/2017/01/05/logo_011_1_20170105110505.gif' width='206' height='30' alt='서울경제' title='' class='' >",
# "thumbnail" : "",
# "title" : "무인화 쓰나미...밤새 잘려나가는 직원들",
# "summary" : "[서울경제] ＃서울 종로구에서 30석 규모의 분식점을 운영하는 이경배(52)씨는 지난해 가을 키오스크(KIOSK)를 들여놓으며 5명이었던 직원 수를 4명으로 줄였다. 키오스크를 설치하기 전 이씨가 지출했던 월평균 인",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "025",
# "officeName" : "중앙일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/025/2018/08/03/logo_025_1_20180803103703.jpg' width='206' height='30' alt='중앙일보' title='' class='' >",
# "thumbnail" : "",
# "title" : "롯데마트 물류비 논란…4000억원 과징금 파장",
# "summary" : "‘어디까지가 납품업체가 부담해야 하는 물류비인가’를 두고 ‘경제 검찰’ 공정거래위원회와 ‘유통 공룡’ 롯데가 맞붙는다. 공정위가 납품업체에 일명 ‘후행(後行) 물류비(유통업체 물류센터에서 매장까지 드는 물류비)’를 ",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "018",
# "officeName" : "이데일리",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/018/2017/01/05/logo_018_1_20170105110505.gif' width='206' height='30' alt='이데일리' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/018/2019/01/22/4296456.jpg?type=nf80_54",
# "title" : "[사내벤처 제2전성시대]①창업 2년만에 \'美CES 혁신상\'…비결은",
# "summary" : "- 美아이비리그 출신 최용준 룰루랩 대표, 2014년 삼성전자 입사 - 입사 2년 후 사내벤처 프로그램 \'C랩\' 통해 룰루랩 창업 - AI 피부솔루션서비스 \'루미니\' 창업 2년 만에 \'CES 혁신상 - 삼성전자 외 ",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "015",
# "officeName" : "한국경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/015/2017/01/05/logo_015_1_20170105110505.gif' width='206' height='30' alt='한국경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/015/2019/01/21/4082128.jpg?type=nf80_54",
# "title" : "최저임금 급등이 부른 \'사상 최대\' 불법체류자",
# "summary" : "작년 10만명 늘어 35만명 돌파 국내 취약계층 일자리 \'위협\' [ 고윤상 기자 ] 한국에서 불법체류 신분으로 살아가는 외국인이 지난해 35만 명을 넘어선 것으로 나타났다. 1년 전(25만 명)에 비해 10만 명 넘",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "028",
# "officeName" : "한겨레",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/028/2017/01/05/logo_028_1_20170105110505.gif' width='206' height='30' alt='한겨레' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/028/2019/01/21/2440506.jpg?type=nf80_54",
# "title" : " 용산참사 10년…김석기 “같은 상황 발생해도 같은 결정”  ",
# "summary" : "당시 서울청장, 기자회견 열어 “용산 화재사고”라고 지칭 “문재인 정권에서 정의란 이름으로 정의 짓밟혀” “2008년 광우병사태 진상규명위 만들어야” 요구 2009년 발생한 ‘용산참사’ 당시 서울경찰청장이었던 김석기",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "016",
# "officeName" : "헤럴드경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/016/2017/01/05/logo_016_1_20170105110505.gif' width='206' height='30' alt='헤럴드경제' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/016/2019/01/22/1490166.jpg?type=nf80_54",
# "title" : "[설 민생안정 대책] 사과·쇠고기 등 성수품 절반가격…KTX 역귀성표 최대 40% 할인",
# "summary" : "전국 농축수산물 특판장 2300곳 15개 핵심 성수품 할인판매 전통시장 주변도로 2시간 주차 ‘코리아 그랜드 세일’ 2월 말까지 지역관광 활성화 유도 나서 전국 농축수산물 특판장 2300여곳에서 다음 달 설을 앞두고",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "029",
# "officeName" : "디지털타임스",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/029/2018/07/18/logo_029_1_20180718140618.jpg' width='206' height='30' alt='디지털타임스' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/029/2019/01/21/2504369.jpg?type=nf80_54",
# "title" : "중국 성장률 6.6%... 28년만에 바닥친 결정적 이유",
# "summary" : "작년 부채축소·무역전쟁 영향 분기별 성장률까지 둔화 추세 올해 5%대 하락 전망도 나와 중국의 지난해 경제성장률이 28년 만에 최저 수준을 기록했다. 21일 중국 국가통계국은 2018년 중국의 실질 국내총생산(GDP",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "353",
# "officeName" : "중앙SUNDAY",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/353/2018/03/17/logo_353_1_20180317103917.png' width='206' height='30' alt='중앙SUNDAY' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "277",
# "officeName" : "아시아경제",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/277/2017/01/05/logo_277_1_20170105110505.gif' width='206' height='30' alt='아시아경제' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "021",
# "officeName" : "문화일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/021/2017/01/05/logo_021_1_20170105110505.gif' width='206' height='30' alt='문화일보' title='' class='' >",
# "thumbnail" : "",
# "title" : "",
# "summary" : "",
# "publishDate" : ""
# },
# {
# "officeId" : "469",
# "officeName" : "한국일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/469/2018/01/26/logo_469_1_20180126174326.gif' width='206' height='30' alt='한국일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/469/2019/01/22/358707.jpg?type=nf80_54",
# "title" : "[단독] 목포 \'문화거리\' 지정 전후, 손혜원측ㆍ외지인 37필지 집중 매입",
# "summary" : "[본보, 목포 역사문화공간 등기 전수조사] 602필지 중 112필지가 외지인… 2017~18년 37필지 거래 몰려 손 의원 지인들 소유 12필지 매입시기 일치… 투기의혹 커져 ‘손혜원 타운’으로 불리는 전남 목포시 ",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "020",
# "officeName" : "동아일보",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/020/2017/01/05/logo_020_1_20170105110505.gif' width='206' height='30' alt='동아일보' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/020/2019/01/22/3194385.jpg?type=nf80_54",
# "title" : "[단독] 손혜원 논란… 목포시의회 지난해 11월 회의록 보니",
# "summary" : "“목포 건물매입 투기적 성향 가진분 많아” “정치인 구입說… 만호동 땅값 엄청 뛰어” 더불어민주당을 탈당한 무소속 손혜원 의원의 ‘목포 부동산 투기’ 의혹과 관련해 목포시의회가 이미 지난해 11월 “(근대역사문화공간",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "032",
# "officeName" : "경향신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/032/2017/01/05/logo_032_1_20170105110505.gif' width='206' height='30' alt='경향신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/032/2019/01/21/2918313.jpg?type=nf80_54",
# "title" : "새 광화문광장, 더 시민 품으로",
# "summary" : "ㆍ세종대왕·이순신 동상 옮기고…3.7배 넓혀 육조거리 복원 추진 서울 광화문광장이 2021년 지금보다 3.7배 넓어지고, 지하는 시민을 위한 거대한 문화공간으로 만들어진다. 광장 한가운데 일렬로 놓인 이순신 장군 동",
# "publishDate" : "20190122"
# },
# {
# "officeId" : "030",
# "officeName" : "전자신문",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/030/2017/01/05/logo_030_1_20170105110505.gif' width='206' height='30' alt='전자신문' title='' class='' >",
# "thumbnail" : "https://imgnews.pstatic.net/image/origin/030/2019/01/21/2777307.jpg?type=nf80_54",
# "title" : "흥행부진 제로페이, 카카오페이·KT 우군 확보",
# "summary" : "소상공인 간편결제 제로페이 사업에 카카오페이, KT, 11번가 등 대형 사업자가 잇달아 합류했다. 가맹점 취약과 소비자 이용 부족으로 여론의 뭇매를 맞은 제로페이지만 이들 사업자 합류로 인프라 확산의 전환점을 맞게 ",
# "publishDate" : "20190122"
# }
# ]
# ,
# "liveTvList" : [
# {
# "officeId" : "422",
# "articleId" : "0000357672",
# "sectionId" : "74f",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/422/2018/01/10/logo_422_1_20180110175610.png' width='206' height='30' alt='연합뉴스TV 뉴스리뷰' title='' class='' >",
# "officeName" : "연합뉴스TV",
# "title" : "\"\'빙상계 적폐\' 적극 수사해야\"…전명규, 의혹 부인",
# "newsKey" : "74f",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/422/2019/01/21/357672.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "\"\'빙상계 적폐\' 적극 수사해야\"…전명규, 의혹 부인 [뉴스리뷰] [앵커] 젊은빙상인연대가 빙상계 성폭력 의혹을 추가로 제기하면서, 가해자들과 전명규 한체대 교수의 관계를 부각시켰습니다. 전명규 교수는 성폭행은 물론",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "449",
# "articleId" : "0000165074",
# "sectionId" : "74b",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/449/2018/01/10/logo_449_1_20180110175910.png' width='206' height='30' alt='채널A 뉴스A' title='' class='' >",
# "officeName" : "채널A",
# "title" : "[현장영상]전명규 “성폭행 몰랐다, 심석희에 미안” (회견 전문)",
# "newsKey" : "74b",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/449/2019/01/21/165074.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "빙상계 성폭력 은폐 의혹에 휩싸인 전명규 한국체대 교수가 자신과 관련된 의혹은 “거짓”이라고 주장했다. 전 교수는 21일 오후 서울 올림픽파크텔에서 긴급 기자회견을 열고 “조재범 전 코치의 상습 폭행 및 성폭행은 알",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "437",
# "articleId" : "0000201132",
# "sectionId" : "742",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/437/2018/01/10/logo_437_1_20180110175610.png' width='206' height='30' alt='JTBC 뉴스룸' title='' class='' >",
# "officeName" : "JTBC",
# "title" : "북·미, 스웨덴 \'밀실 담판\'…비핵화 범위-상응 조치 \'집중 조율\'",
# "newsKey" : "742",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/437/2019/01/21/201132.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[앵커] 스웨덴의 외진 산골에서 2차 북·미정상회담을 위한 실무협상이 사흘째 이어지고 있습니다. 호수에 떠 있는 섬 모양의 요새 같은 곳입니다. 현재 최선희 북한 외무성 부상과 비건 미국 특별대표가 이곳에서 말 그대",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "056",
# "articleId" : "0010663346",
# "sectionId" : "355",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/056/2018/01/10/logo_056_1_20180110175610.png' width='206' height='30' alt='KBS 뉴스9' title='' class='' >",
# "officeName" : "KBS",
# "title" : "“빙상계 성폭력 피해 5건 더 있다…전명규 전 부회장이 묵인”",
# "newsKey" : "355",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/056/2019/01/21/10663346.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[앵커] 빙상계에서 심석희 선수 말고도 성폭력 피해자가 5명이 더 있다는 폭로가 나왔습니다. 젊은 빙상인연대가 오늘(21일) 밝힌 내용입니다. 이들은 성폭력 가해 코치들이 아무런 제재나 불이익도 받지않았다면서 그 배",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "214",
# "articleId" : "0000910496",
# "sectionId" : "370",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/214/2018/01/10/logo_214_1_20180110175710.png' width='206' height='30' alt='MBC 뉴스데스크' title='' class='' >",
# "officeName" : "MBC",
# "title" : "\"한국이 공격하려던 증거\"라며 내놓곤…\"협의 그만\"",
# "newsKey" : "370",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/214/2019/01/21/910496.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[뉴스데스크]◀ 앵커 ▶ 일본 방위성이 조금 전, 한국의 광개토대왕함이 쏜 공격용 레이더를 감지한 일본 초계기의 탐지음이라면서 음향 파일을 하나 공개했습니다. 먼저 들어보시죠. 관련 보도를 전해 드리기 전에 배경 설",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "057",
# "articleId" : "0001320181",
# "sectionId" : "74e",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/057/2018/01/10/logo_057_1_20180110175810.png' width='206' height='30' alt='MBN 뉴스8' title='' class='' >",
# "officeName" : "MBN",
# "title" : "김주하 앵커가 전하는 1월 21일 뉴스8 주요뉴스",
# "newsKey" : "74e",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/057/2019/01/21/1320181.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "▶ 일본 레이더 탐지음 공개 \"협의 중단\" 우리 군이 자국의 해상 초계기에 공격용 레이더를 겨냥했다고 주장하는 일본이, 증거로 레이더 탐지음을 공개했습니다. 또한 \"더이상 한국과는 협의를 진행하지 않겠다\"고 밝혔습니",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "055",
# "articleId" : "0000705231",
# "sectionId" : "371",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/055/2018/01/10/logo_055_1_20180110175610.png' width='206' height='30' alt='SBS 8뉴스' title='' class='' >",
# "officeName" : "SBS",
# "title" : "오늘의 주요뉴스",
# "newsKey" : "371",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/055/2019/01/21/705231.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "1. \'젊은 빙상인 연대\'가 성폭력 사례를 추가 공개하고 은폐 의혹의 중심에 있는 전명규 한체대 교수에 대한 수사를 촉구했습니다. 전 교수는 긴급 기자 회견을 통해 대부분의 의혹을 강하게 부인했는데 전 교수와 대한체",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "448",
# "articleId" : "0000264423",
# "sectionId" : "750",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/448/2018/08/30/logo_448_1_20180830162730.png' width='206' height='30' alt='TV조선 뉴스9' title='' class='' >",
# "officeName" : "TV조선",
# "title" : "서울시, 광화문광장 4배로 확대…GTX역사 신설 추진",
# "newsKey" : "750",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/448/2019/01/21/264423.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[앵커] 오늘 뉴스9은 먼저 사진 한장 보여드리겠습니다. 1970년대 광화문 앞 세종대로 모습입니다. 예전에는 이렇게 중앙분리대만 있었던 곳이, 10년 전에 이렇게 지금과 같이 광장으로 새롭게 조성이 됐지요. 그런데",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# },
# {
# "officeId" : "052",
# "articleId" : "0001243820",
# "sectionId" : "751",
# "logoUrl" : "<img src='https://mimgnews.pstatic.net/image/upload/office_logo/052/2018/01/10/logo_052_1_20180110175810.png' width='206' height='30' alt='YTN 뉴스나이트' title='' class='' >",
# "officeName" : "YTN",
# "title" : "[나이트] 내일브리핑",
# "newsKey" : "751",
# "thumbnail" : "<img src='https://imgnews.pstatic.net/image/origin/052/2019/01/21/1243820.jpg?type=nf255_134' width='255' height='134' alt='' onError=\"javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_255x134.png';this.style.width=255;this.style.height=134;\">",
# "summary" : "[앵커] 내일은 어떤 뉴스들이 눈길을 끌지 미리 짚어봅니다. 내일브리핑입니다. ■인권위 스포츠 인권 긴급 기자회견 최근 잇따르는 체육계 성폭력 문제와 관련해 국가인권위원회가 향후 대책과 입장을 발표합니다. 국가인권위",
# "onairStatus" : "REPLAY",
# "nextLiveTime" : ""
# }
# ]
# };
# </script>
# </div>
# <script type="text/javascript">
# 	// page onload 시에 home timelate에서 사용하는 스크립트를 초기화 시켜준다.
# 	jindo.$Fn(function(){
# 		try {
# 			news.home.TopTimelate.Controller.init(_oTopComponentData);
# 		} catch (e) { }
# 	}).attach(window, "load");
# </script>
# <div class="main_space"></div>
# <div class="main" id="container">
# <hr/>
# <div class="main_content main_content_new" id="main_content">
# <div class="main_component droppable" id="today_main_news">
# <div class="com_header">
# <h4 class="tit_h4 tit_main1"><strong>이 시각 주요뉴스</strong></h4>
# <span class="small">최종 <em>2019.01.22 11:21</em></span>
# </div>
# <div id="pan_today_main_news">
# <div class="newsnow" style="position:relative;">
# <div class="newsnow_imgarea">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=003&amp;sid1=102&amp;aid=0009023930&amp;mid=shm&amp;mode=LSD&amp;nh=20190122104939"> <img alt="백석역 열수송관 사고 원인은 '용접 불량'" height="190" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_300x190.png';" src="https://imgnews.pstatic.net/image/upload/item/2019/01/22/104936982_2.jpg?type=f270_166" width="300">
# <div class="newsnow_img_mask">
# <div class="newsnow_img_mask_bg"></div>
# <p class="newsnow_img_mask_p"> 백석역 열수송관 사고 원인은 '용접 불량'</p>
# </div>
# <div class="newsnow_edge"></div> </img></a>
# </div>
# <ul class="newsnow_txarea" id="text_today_main_news_801001">
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=001&amp;sid1=100&amp;aid=0010593415&amp;mid=shm&amp;mode=LSD&amp;nh=20190122102244"><strong>'설민생대책' 위기지역·중기·소상공인·저소득층에 35조 푼다</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=100&amp;gid=1079155&amp;mid=hot&amp;viewType=pc&amp;cid=1079165&amp;nh=20190122103012"><strong>北美, 정상회담 준비 본격화…스웨덴 이어 판문점서 마주앉나</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=001&amp;sid1=101&amp;aid=0010593305&amp;mid=shm&amp;mode=LSD&amp;nh=20190122093638"><strong>한은 "작년 1인당 국민소득 3만1천달러 넘은 듯"</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=001&amp;sid1=102&amp;aid=0010593426&amp;mid=shm&amp;mode=LSD&amp;nh=20190122101251"><strong>내일 양승태 영장심사 법원 '딜레마'…발부·기각 모두 후폭풍</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=056&amp;sid1=103&amp;aid=0010663506&amp;mid=shm&amp;mode=LSD&amp;nh=20190122100938"><strong>추위 풀리니 또 미세먼지 '나쁨'…건조특보 확대</strong></a>
# </div> </li>
# </ul>
# </div>
# <div class="newsnow" style="position:relative;display:block;">
# <div class="newsnow_imgarea">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/photogallery/index.nhn?cid=987213&amp;nh=20190122103117#421_0003796964"> <img alt="상고대가 만든 마법같은 풍경" height="190" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_300x190.png';" src="https://imgnews.pstatic.net/image/upload/item/2019/01/22/103055178_0003796964_001_20190122102645781.jpg?type=f270_166" width="300">
# <div class="newsnow_img_mask">
# <div class="newsnow_img_mask_bg"></div>
# <strong class="r_ico r_pho_medium">포토갤러리 기사</strong>
# <p class="newsnow_img_mask_p"> 상고대가 만든 마법같은 풍경</p>
# </div>
# <div class="newsnow_edge"></div> </img></a>
# </div>
# <ul class="newsnow_txarea" id="text_today_main_news_428288">
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=003&amp;sid1=100&amp;aid=0009023668&amp;mid=shm&amp;mode=LSD&amp;nh=20190122101242"><strong>이낙연, 손혜원 '목포 투기' 의혹에 "잘못 확인되면 법대로 대처"</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=003&amp;sid1=101&amp;aid=0009023763&amp;mid=shm&amp;mode=LSD&amp;nh=20190122101950"><strong>주택증여 작년 11만1863건, 역대 최다…서울아파트 증여 2배↑</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/read.nhn?oid=001&amp;sid1=100&amp;aid=0010593098&amp;mid=shm&amp;mode=LSD&amp;nh=20190122103025"><strong>작년 로또 판매액 3조9천658억원…15년만에 신기록 썼다</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=104&amp;mid=hot&amp;viewType=pc&amp;cid=334823&amp;nh=20190122104651#1083232"><strong>브렉시트 '도돌이표'…메이 '플랜B'는 결국 '플랜A'였다</strong></a>
# </div> </li>
# <li>
# <div class="newsnow_tx_inner">
# <a class="nclicks(hom.headcont)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=101&amp;mid=hot&amp;viewType=pc&amp;cid=957181&amp;nh=20190122095619"><strong>'미분양 빨간불' 반년만에 16곳→19곳…수도권 줄고 지방은 확산</strong></a>
# </div> </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclicks(hom.order)" title="이동">이동</span>
# <a class="up_off nclicks(hom.order)" href="#" title="위로">위로</a>
# <a class="down nclicks(hom.order)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_politics">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(pol.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h4>
# <span class="tit_sub">
# <a class="nclicks(pol.common)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">일반</a><span class="bar"></span>
# <a class="nclicks(pol.party)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당</a><span class="bar"></span>
# <a class="nclicks(pol.chung)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">청와대</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163534', 'airsGParam', '0', 'news_sec_v2.0', 'JjeuTdOmTkh1kzBz')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=008&amp;aid=0004163534">
# <img alt='홍준표 "집안 망해갈 때 뭐했나"…황교안·오세훈에 연일 맹공' height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/008/2019/01/22/4163534.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163534', 'airsGParam', '0', 'news_sec_v2.0', 'JjeuTdOmTkh1kzBz')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=008&amp;aid=0004163534">홍준표 "집안 망해갈 때 뭐했나"…황교안·오세훈에 연일 맹공</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163534', 'airsGParam', '0', 'news_sec_v2.0', 'JjeuTdOmTkh1kzBz')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=586&amp;aid=0000004724">
# <strong>F-35A 전투기, 쥐도 새도 모르게 北 영공 넘나든다</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">시사저널</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163534', 'airsGParam', '0', 'news_sec_v2.0', 'JjeuTdOmTkh1kzBz')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=079&amp;aid=0003187565">
# <strong>'비건-최선희 라인' 가동…韓 중재역 가능성 확인</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">노컷뉴스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163534', 'airsGParam', '0', 'news_sec_v2.0', 'JjeuTdOmTkh1kzBz')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0010593647">
# <strong>'무소식이 희소식?'…北, 美와 정상회담 합의·실무협의에 침묵</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">연합뉴스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163534', 'airsGParam', '0', 'news_sec_v2.0', 'JjeuTdOmTkh1kzBz')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0003797057">
# <strong>홍준표 "당권주자들 비겁하고 뻔뻔해"…오세훈·황교안 동시 저격</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴스1</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163534', 'airsGParam', '0', 'news_sec_v2.0', 'JjeuTdOmTkh1kzBz')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=014&amp;aid=0004164790">
# <strong>한국당 "孫, 투기 의혹·부친 유공자 검찰 고발"...이낙연 "법대로 대처"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">파이낸셜뉴스</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(soc.move)" title="이동">이동</span>
# <a class="up nclicks(soc.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(soc.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_economy">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(eco.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101">경제</a></h4>
# <span class="tit_sub">
# <a class="nclicks(eco.common)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=263">일반</a><span class="bar"></span>
# <a class="nclicks(eco.finance)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=259">금융</a><span class="bar"></span>
# <a class="nclicks(eco.domestic)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=310">생활경제</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163545', 'airsGParam', '0', 'news_sec_v2.0', '3Ked31desbwQ2fVU')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=008&amp;aid=0004163545">
# <img alt='넥사, 베트남 나노젠과 신약개발 "바이오 퍼스트무브 목표"' height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/008/2019/01/22/4163545.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163545', 'airsGParam', '0', 'news_sec_v2.0', '3Ked31desbwQ2fVU')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=008&amp;aid=0004163545">넥사, 베트남 나노젠과 신약개발 "바이오 퍼스트무브 목표"</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163545', 'airsGParam', '0', 'news_sec_v2.0', '3Ked31desbwQ2fVU')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=277&amp;aid=0004398903">
# <strong>"최고수준 시장개방해야" 가입 문턱 높아진 CPTPP…美 가입 여부 변수</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아시아경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163545', 'airsGParam', '0', 'news_sec_v2.0', '3Ked31desbwQ2fVU')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=014&amp;aid=0004164827">
# <strong>삼한사미로 가전 매출 순위 '급변'</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">파이낸셜뉴스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163545', 'airsGParam', '0', 'news_sec_v2.0', '3Ked31desbwQ2fVU')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=277&amp;aid=0004398902">
# <strong>단디바이오, 나노젠 업고 동남아 진출</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아시아경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163545', 'airsGParam', '0', 'news_sec_v2.0', '3Ked31desbwQ2fVU')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=277&amp;aid=0004398897">
# <strong>KCGI, 한진에 '유휴자산' 정리하라지만…기초체력 약화 우려도</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아시아경제</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','880000C2_000000000000000004163545', 'airsGParam', '0', 'news_sec_v2.0', '3Ked31desbwQ2fVU')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=277&amp;aid=0004398896">
# <strong>작년 담배 수입액 역대 최대…전자담배가 '불' 붙였다</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">아시아경제</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(pol.move)" title="이동">이동</span>
# <a class="up nclicks(pol.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(pol.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_society">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(soc.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=102">사회</a></h4>
# <span class="tit_sub">
# <a class="nclicks(soc.common)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=257">일반</a><span class="bar"></span>
# <a class="nclicks(soc.edu)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=250">교육</a><span class="bar"></span>
# <a class="nclicks(soc.labor)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=251">노동</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','8800010E_000000000000000001490189', 'airsGParam', '0', 'news_sec_v2.0', 'sbcaSDEUiYnEgnYJ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=016&amp;aid=0001490189">
# <img alt="대학취업률 6년연속 하락…‘SKY’ 취업 불패도 옛말" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/016/2019/01/22/1490189.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','8800010E_000000000000000001490189', 'airsGParam', '0', 'news_sec_v2.0', 'sbcaSDEUiYnEgnYJ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=016&amp;aid=0001490189">대학취업률 6년연속 하락…‘SKY’ 취업 불패도 옛말</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','8800010E_000000000000000001490189', 'airsGParam', '0', 'news_sec_v2.0', 'sbcaSDEUiYnEgnYJ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=079&amp;aid=0003187585">
# <strong>'음주운전만 5번' 술 취해 또 운전대 잡은 30대 덜미</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">노컷뉴스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8800010E_000000000000000001490189', 'airsGParam', '0', 'news_sec_v2.0', 'sbcaSDEUiYnEgnYJ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=422&amp;aid=0000357743">
# <strong>[자막뉴스] "엄마 돈 보내주세요"…'카톡피싱' 주의보</strong>
# </a>
# <span class="writing">연합뉴스TV</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8800010E_000000000000000001490189', 'airsGParam', '0', 'news_sec_v2.0', 'sbcaSDEUiYnEgnYJ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=422&amp;aid=0000357742">
# <strong>[자막뉴스] "투기 vs 마중물" 목포 시민 엇갈린 시선</strong>
# </a>
# <span class="writing">연합뉴스TV</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8800010E_000000000000000001490189', 'airsGParam', '0', 'news_sec_v2.0', 'sbcaSDEUiYnEgnYJ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=003&amp;aid=0009024132">
# <strong>청주 한 원룸서 60대 숨진 채 발견…경찰 수사</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">뉴시스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','8800010E_000000000000000001490189', 'airsGParam', '0', 'news_sec_v2.0', 'sbcaSDEUiYnEgnYJ')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=025&amp;aid=0002879874">
# <strong>서울에 눈이 사라졌다…이례적 겨울 가뭄 왜?</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">중앙일보</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(eco.move)" title="이동">이동</span>
# <a class="up nclicks(eco.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(eco.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_life">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(lif.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=103">생활/문화</a></h4>
# <span class="tit_sub">
# <a class="nclicks(lif.health)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=241">건강</a><span class="bar"></span>
# <a class="nclicks(lif.travel)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=237">여행</a><span class="bar"></span>
# <a class="nclicks(lif.car)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=239">자동차</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','88000149_000000000000000000729714', 'airsGParam', '0', 'news_sec_v2.0', '8TSXwEyXKIPTSS6v')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=215&amp;aid=0000729714">
# <img alt="내 몸이 틀어져있다?  원인을 찾아 '균형'을 맞추자!" height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/215/2019/01/22/729714.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','88000149_000000000000000000729714', 'airsGParam', '0', 'news_sec_v2.0', '8TSXwEyXKIPTSS6v')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=215&amp;aid=0000729714">내 몸이 틀어져있다?  원인을 찾아 '균형'을 맞추자!</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# <a class="nclicks('hom.airscont','88000149_000000000000000000729714', 'airsGParam', '0', 'news_sec_v2.0', '8TSXwEyXKIPTSS6v')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=346&amp;aid=0000024394">
# <strong>급히 응급실 찾는 '충수돌기염'… "24시간 안에 수술받으면 돼"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">헬스조선</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000149_000000000000000000729714', 'airsGParam', '0', 'news_sec_v2.0', '8TSXwEyXKIPTSS6v')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=025&amp;aid=0002879864">
# <strong>"치매냐 아니냐…16년 전 당신 피는 알 수도 있다"</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">중앙일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000149_000000000000000000729714', 'airsGParam', '0', 'news_sec_v2.0', '8TSXwEyXKIPTSS6v')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=021&amp;aid=0002379317">
# <strong>&lt;지식카페&gt;제기에 과일 놓고 초 밝힌 拜火敎 제상… 우리 상차림 ‘닮은꼴’</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">문화일보</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000149_000000000000000000729714', 'airsGParam', '0', 'news_sec_v2.0', '8TSXwEyXKIPTSS6v')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=014&amp;aid=0004164756">
# <strong>박능후 복지부 장관과 류영진 식약처장, 각각 제약사 연구소와 바이오 공장 방문</strong>
# </a>
# <i class="icon_photo">포토</i>
# <span class="writing">파이낸셜뉴스</span>
# </li>
# <li>
# <a class="nclicks('hom.airscont','88000149_000000000000000000729714', 'airsGParam', '0', 'news_sec_v2.0', '8TSXwEyXKIPTSS6v')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=014&amp;aid=0004164741">
# <strong>[fn선임기자가 만난사람] 에디슨모터스는 전기차 핵심 배터리 기술력 독보적</strong>
# </a>
# <span class="writing">파이낸셜뉴스</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="btn_move">
# <span class="move nclick(lif.move)" title="이동">이동</span>
# <a class="up nclicks(lif.up)" href="#" title="위로">위로</a>
# <a class="down nclicks(lif.down)" href="#" title="아래로">아래로</a>
# </div>
# </div>
# <div class="main_component droppable" id="section_world">
# <div class="com_header">
# <h4 class="tit_sec"><a class="nclicks(wor.title)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=104">세계</a></h4>
# <span class="tit_sub">
# <a class="nclicks(wor.common)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=104&amp;sid2=322">일반</a><span class="bar"></span>
# <a class="nclicks(wor.issue)" href="/main/hotissue/sectionList.nhn?mid=hot&amp;sid1=104&amp;cid=845614">지구촌 화제</a>
# </span>
# </div>
# <div class="com_list">
# <dl class="mtype_img">
# <dt>
# <a class="nclicks('hom.airscont','88000127_000000000000000009024022', 'airsGParam', '0', 'news_sec_v2.0', 'LuJe40sbD32vnf4N')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=003&amp;aid=0009024022">
# <img alt='日 "초계기, 작년 4~8월 광개토대왕함 접근했지만 항의 없었다"' height="140" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_220x140.png';this.style.width=220;this.style.height=140;" src="https://mimgnews.pstatic.net/image/origin/003/2019/01/22/9024022.jpg?type=nf220_140" width="220"/>
# <span class="trans_border"></span>
# </a>
# </dt>
# <dd>
# <a class="nclicks('hom.airscont','88000127_000000000000000009024022', 'airsGParam', '0', 'news_sec_v2.0', 'LuJe40sbD32vnf4N')" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=104&amp;oid=003&amp;aid=0009024022">日 "초계기, 작년 4~8월 광개토대왕함 접근했지만 항의 없었다"</a>
# </dd>
# </dl>
# <div class="mtype_list_wide">
# <ul class="mlist2 no_bg">
# <li>
# ...
# , 'id':'1078993'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&dummy=1711271013&mid=hot&cid=1064671&nh=20180705024959"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/104600244_174451333_1.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1064671&dummy=1711271013" >'
# +'\uAE40\uC885\uCCA0 \uAE30\uC790\uC758 \uD4E8\uC804 \uB9AC\uB354\uC2ED&\uB864\uBAA8\uB378</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078903'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=1064777&nh=20180705025014"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/104638178_0002413936_001_20180615163006322.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1064777" >'
# +'\uACFD\uB178\uD544 \uAE30\uC790\uC758 \uBBF8\uB798\uCC3D</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1079007'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=103&mid=hot&cid=1047810&nh=20180705025025"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/04/25/141839774_150349068_3.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=103&cid=1047810" >'
# +'\uBC30\uD55C\uCCA0 \uAE30\uC790\uC758 \uD55C\uAD6D\uCD08\uC0C1\uD654 \uD1BA\uC544\uBCF4\uAE30</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1079006'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=1000701&nh=20180705025040"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/104729590_111031797_2.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1000701" >'
# +'\uC548\uB450\uC6D0 \uAE30\uC790\uC758 \uBA3C \uB4EF \uAC00\uAE4C\uC6B4 \uBC29\uC0B0\uC5C5\uCCB4 \uBCA0\uC77C \uBC97\uAE30\uAE30</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1079009'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=1047811&nh=20180705025046"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/04/25/144810089_094729784_4.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1047811" >'
# +'\uC774\uADFC\uC6B0 \uAE30\uC790\uC758 \uACBD\uC81C\uD559\uC73C\uB85C \uC138\uC0C1\uC77D\uAE30</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078915'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=1024480&nh=20180705025102"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/104847598_092210791_1.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1024480" >'
# +'\uC774\uC9C4\uC6B0 \uAE30\uC790\uC758 \uC808\uBCBD\uAC00(\u7D76\u58C1\u6B4C)</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1079008'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=1081825&nh=20180816121231"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/04/25/141636888_0002407462_001_20180424201007021.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1081825" >'
# +'\uC591\uC120\uC544 \uAE30\uC790\uC758 \uC0DD\uC0DD\uC721\uC544</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078914'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=952414&nh=20180705025125"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/104958429_104212345_1.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=952414" >'
# +'\uC815\uC9C4\uAC74 \uAE30\uC790\uC758 \uBA38\uB2C8 \uC778\uC0AC\uC774\uD2B8</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078996'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&dummy=1804240002&mid=hot&cid=1014465&nh=20180705025133"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/04/25/142251923_102308592_1.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1014465&dummy=1804240002" >'
# +'\uCD5C\uAE30\uC131\uC758 \uD5C8\uBE0C\u8ECA</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078995'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=1008884&nh=20180705025141"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/105836599_140956069_1.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=1008884" >'
# +'\uCD5C\uC740\uC218 \uAE30\uC790\uC758 \uBBF8\uB798\uC774\uC57C\uAE30</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078997'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&dummy=1804240001&mid=hot&cid=891791&nh=20180705025147"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/110249340_104120726_1.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=891791&nh=20171201095844&dummy=1804240001" >'
# +'\uD604\uBB38\uD559 \uAE30\uC790\uC758 \uB3C8\uB418\uB294 \uC911\uAD6D\uACBD\uC81C</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1079054'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=103&mid=hot&cid=74098&nh=20180705025155"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2018/06/22/110207694_0002411839_002_20180530210508428.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=103&cid=74098" >'
# +'\uACFD\uC724\uC12D \uAE30\uC790\uC758 \uC0AC\uC9C4\uB9C8\uC744</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# items.push(new news.common.RollingItem({
# 'componentId':'1078913'
# , 'id':'1078998'
# , 'titleSrc' : '전문기자 칼럼'
# , 'imgSrc':
# '<div class="column_thumb"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?sid1=110&mid=hot&cid=948201&nh=20180705025200"'
# +'>'
# +'<img src="https://imgnews.pstatic.net/image/upload/item/2017/12/12/145034224_1.jpg" width="300" height="92" alt=""  id="IMG_ROLLING_IMG_1078913_0" />'
# +'<span class="trans_border"></span></a></div>'
# +'<h5 class="normal"><a class="nclicks(rig.column)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&sid1=110&cid=948201" >'
# +'\uC624\uCCA0\uC6B0 \uAE30\uC790\uC758 \uACFC\uD559\uC77D\uAE30</a>'
# +' '
# +' </h5>'
# , 'textSrc':' '
# }));
# rolling_1078913 = new news.common.Rolling({'rollingItems':items, 'showId':'ROLLING', 'rollingCount':1, 'interval':0, 'isEffectAppear':false});
# }
# executeRolling1078913();
# jindo.$('BUTTON_ROLLING_PREV_'+1078913).onclick = function (e){jindo.$Event(e).stopDefault(); rolling_1078913.backRolling(rolling_1078913);}
# jindo.$('BUTTON_ROLLING_NEXT_'+1078913).onclick = function (e){jindo.$Event(e).stopDefault(); rolling_1078913.rolling(rolling_1078913);}
# </script>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.nhn"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.nhn?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.nhn?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&amp;sid1=100&amp;cid=909906&amp;decorator=ombudsman&amp;confirm=true"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.nhn"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <div class="da" id="rightDoubleDA" style="display: none"></div>
# <script type="text/javascript">
#             try{
#                 jindo.$("doubleDA").innerHTML = '<div id="daHome_300250" name="daHome_300250" style="width: 300px; height: 250px;"><iframe id="home300250" name="home300250" src="https://veta.naver.com/fxshow?su=SU10306&calp=home" width="300" height="250" marginheight="0" marginwidth="0" border="0" frameborder="0" scrolling="no" align="center" title="우측_뉴스홈_더블플레이광고" data-veta-preview="news_home_02"></iframe></div>';
#             }catch(e){}
#         </script>
# <div class="rightBottomDouble" style="margin-top:36px;"><div data-dom-type="doubleplay_bottom" id="doubleHome300250" name="doubleHome300250" title="더블플레이하단광고"></div></div>
# </div>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# <div class="index_myscrap">
# <a class="spr nclicks(fot.scrap)" href="/main/scrap/index.nhn">마이스크랩</a>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.nhn">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.nhn?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 정연아</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
# new news.lnb.NewsSearchController('lnb.searchForm');
#
#
#
# //var lnb_weatherRolling = new news.lnb.LineRolling('lnb.weather',{size:26,moveSize:3,moveInterval:30});
# var lnb_mainnewsRolling = new news.lnb.LineRolling('lnb.mainnews',{size:17,moveSize:2,moveInterval:30,isRandomStart:true});
# var lnb_Rolling = new news.lnb.SynchronizedRolling({interval:3000});
# //lnb_Rolling.push(lnb_weatherRolling);
# lnb_Rolling.push(lnb_mainnewsRolling);
# lnb_Rolling.start();
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.nhn'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.nhn'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#
#
#
# news.home.DragController.init();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </div>
# </body>
# </html>

# %%
for item in soup.select('text_today_main_news_801001'):
    print("기사제목:",text_today_main_news_801001.newsnow_tx_inner.string)
