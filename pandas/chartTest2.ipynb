# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt     
import matplotlib

matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus']=False

# %%
height = [165,177,160,180,185,155,172]
weight = [62,67,55,74,90,43,64]
sList = [100,150,200,250,300,350,400]
colors=['r','g','b','k','m','y','c']
plt.scatter(height,weight,s = sList, c=colors ,alpha=0.5)  # alpha = 투명도
plt.xlabel('키')
plt.ylabel('몸무게')
plt.grid(True)
plt.show()

# %% [markdown]
# 표준체중(kg)={신장(cm)-100}x0.85
# 비만도 (%) = 현재체중/표준체중x100
#
# 비만도가
# 90이하:저체중,
# 90~110:정상,
# 110~120:과체중,
# 120이상:비만

# %%
def obsityFn(h, w):
    stdW= (h-100)*0.85
    biman = w/stdW*100
    if biman<=90:
        return '저체중'
    elif 90<biman <=110:
        return '정상'
    elif 110<biman<=120:
        return '과체중'
    else:
        return '비만'

# %%
obsityFn(174,66)
# Out:
# '정상'

# %%
height = [165,177,160,180,185,155,172]
weight = [62,67,55,74,90,43,64]
sList = [100,150,200,250,300,350,400]  # 동그라미(데이터) 크기
colors=['r','g','b','k','m','y','c']
plt.scatter(height,weight,s = sList, c=colors ,alpha=0.5)  # alpha = 투명도
plt.xlabel('키')
plt.ylabel('몸무게')
plt.grid(True)
for x,y in zip( height,weight ):
    plt.text(x,y,'%s' %obsityFn(x, y))
plt.show()

# %%
x=[4,2,5,10,1] #문자열이면 순서대로 숫자면 순서대로정렬
y=[5,10,15,20,25]
plt.plot([str(n) for n in x],y)
plt.show()

# %%
# 리스트안에 for루프
data =[4,2,5,10,1]
mydata = [n*10 for n in data]
print(mydata)
mydata1 = [str(n) for n in data]
print(mydata1)
# Out:
# [40, 20, 50, 100, 10]
# ['4', '2', '5', '10', '1']
